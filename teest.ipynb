# %%
from ase.io import read, iread, write

tiny_6_step_traj = '/Users/chrisdavies/Desktop/lsp/4ns/lsp_298_first_five_steps.custom'
large_16gb_traj = '/Users/chrisdavies/Desktop/lsp/4ns/lsp_298.custom'

# %%
atoms = read(tiny_6_step_traj, index=':')
print(len(atoms))
# Out:
# 6

# %%
import cProfile

cProfile.run('read("/Users/chrisdavies/Desktop/lsp/4ns/lsp_298.custom", index = slice(0,100))', sort='time')
# Out:
# Using new version
#          2436719 function calls (2436222 primitive calls) in 11.370 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     40002    4.677    0.000    8.461    0.000 lammpsrun.py:488(find_timestep_positions)
#     40156    3.524    0.000    5.894    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#     40157    2.351    0.000    2.351    0.000 {built-in method _codecs.utf_8_decode}
#       100    0.238    0.002    0.238    0.002 {built-in method numpy.core._multiarray_umath._load_from_filelike}
#       100    0.210    0.002    0.272    0.003 symbols.py:19(symbols2numbers)
#       101    0.088    0.001   11.347    0.112 lammpsrun.py:470(read_lammps_dump_text)
#     40002    0.050    0.000    0.054    0.000 {method 'seek' of '_io.TextIOWrapper' objects}
#   1023783    0.040    0.000    0.040    0.000 {built-in method builtins.isinstance}
# ...

# %%
import cProfile

cProfile.run('read("/Users/chrisdavies/Desktop/lsp/4ns/lsp_298.custom", index = 0)', sort='time')
# Out:
# Using new version
#          102552 function calls in 8.629 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     40002    4.753    0.000    8.612    0.000 lammpsrun.py:488(find_timestep_positions)
#       156    2.223    0.014    3.857    0.025 {method 'read' of '_io.TextIOWrapper' objects}
#       157    1.633    0.010    1.633    0.010 {built-in method _codecs.utf_8_decode}
#         2    0.004    0.002    8.623    4.311 lammpsrun.py:470(read_lammps_dump_text)
#        34    0.003    0.000    0.003    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.002    0.002    0.002    0.002 {built-in method numpy.core._multiarray_umath._load_from_filelike}
#         1    0.002    0.002    0.003    0.003 symbols.py:19(symbols2numbers)
#     40001    0.002    0.000    0.002    0.000 {method 'start' of 're.Match' objects}
#         2    0.002    0.001    0.002    0.001 {built-in method io.open}
# ...

# %%
import cProfile

cProfile.run('read("/Users/chrisdavies/Desktop/lsp/4ns/lsp_298.custom", index = 0)', sort='time')
# Out:
#          824828327 function calls in 327.333 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     40001  168.368    0.004  168.368    0.004 {built-in method numpy.core._multiarray_umath._load_from_filelike}
#     40001   82.597    0.002  105.401    0.003 symbols.py:19(symbols2numbers)
# 408730933   14.983    0.000   15.004    0.000 {built-in method builtins.isinstance}
#     40001   13.709    0.000   13.709    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    8.278    8.278  324.102  324.102 lammpsrun.py:449(read_lammps_dump_text)
#     40001    8.159    0.000  138.562    0.003 lammpsrun.py:220(lammps_data_to_ase_atoms_typed)
#    520013    8.027    0.000    8.027    0.000 {built-in method numpy.array}
# 408930223    7.890    0.000    7.890    0.000 {method 'append' of 'list' objects}
#         1    4.629    4.629    4.630    4.630 lammpsrun.py:472(<listcomp>)
# ...
